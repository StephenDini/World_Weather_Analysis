# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 723

# %%
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

import pprint as pp
# Import the API key.

from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | zeya
# Processing Record 2 of Set 1 | ossora
# Processing Record 3 of Set 1 | bystryy istok
# Processing Record 4 of Set 1 | nchelenge
# Processing Record 5 of Set 1 | aswan
# Processing Record 6 of Set 1 | hami
# Processing Record 7 of Set 1 | kapaa
# Processing Record 8 of Set 1 | shingu
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | ballina
# Processing Record 11 of Set 1 | kaitangata
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | finschhafen
# Processing Record 15 of Set 1 | nemuro
# Processing Record 16 of Set 1 | mumbwa
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | beloha
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | adre
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | pimenta bueno
# Processing Record 25 of Set 1 | inhambane
# Processing Record 26 of Set 1 | huayang
# Processing Record 27 of Set 1 | nantucket
# Processing Record 28 of Set 1 | los cedrales
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | sikeston
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | chapais
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | hobart
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | torbay
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | san marco in lamis
# Processing Record 40 of Set 1 | lydenburg
# Processing Record 41 of Set 1 | yulara
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | les escoumins
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | murgab
# Processing Record 46 of Set 1 | boffa
# Processing Record 47 of Set 1 | kahului
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | riyadh
# Processing Record 50 of Set 1 | gat
# Processing Record 1 of Set 2 | zyryanka
# Processing Record 2 of Set 2 | lebu
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | morehead
# Processing Record 5 of Set 2 | puerto ayora
# Processing Record 6 of Set 2 | ibra
# Processing Record 7 of Set 2 | bengkulu
# Processing Record 8 of Set 2 | pilao arcado
# City not found. Skipping...
# Processing Record 9 of Set 2 | vostok
# Processing Record 10 of Set 2 | nikolskoye
# Processing Record 11 of Set 2 | tamiahua
# Processing Record 12 of Set 2 | saint george
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | tongren
# Processing Record 15 of Set 2 | chiredzi
# Processing Record 16 of Set 2 | chuy
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 2 | kipushi
# Processing Record 20 of Set 2 | balabac
# Processing Record 21 of Set 2 | vaini
# Processing Record 22 of Set 2 | sneek
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | chokurdakh
# Processing Record 25 of Set 2 | ballyshannon
# Processing Record 26 of Set 2 | severodvinsk
# Processing Record 27 of Set 2 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | barcelona
# Processing Record 31 of Set 2 | qaanaaq
# Processing Record 32 of Set 2 | avarua
# Processing Record 33 of Set 2 | aitolikon
# City not found. Skipping...
# Processing Record 34 of Set 2 | ancud
# Processing Record 35 of Set 2 | port alfred
# Processing Record 36 of Set 2 | peniche
# Processing Record 37 of Set 2 | coihaique
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | bonavista
# Processing Record 40 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 41 of Set 2 | pangody
# Processing Record 42 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 2 | sakaiminato
# Processing Record 44 of Set 2 | vila franca do campo
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | saint-joseph
# Processing Record 47 of Set 2 | aksha
# Processing Record 48 of Set 2 | faya
# Processing Record 49 of Set 2 | busselton
# Processing Record 50 of Set 2 | comodoro rivadavia
# Processing Record 1 of Set 3 | westport
# Processing Record 2 of Set 3 | grand gaube
# Processing Record 3 of Set 3 | ribeira grande
# Processing Record 4 of Set 3 | golden gate
# Processing Record 5 of Set 3 | kavieng
# Processing Record 6 of Set 3 | hovd
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | fort nelson
# Processing Record 9 of Set 3 | mezen
# Processing Record 10 of Set 3 | kaeo
# Processing Record 11 of Set 3 | kadnikov
# Processing Record 12 of Set 3 | vila
# Processing Record 13 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | lagoa
# Processing Record 16 of Set 3 | barrow
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | hermanus
# Processing Record 19 of Set 3 | kysyl-syr
# Processing Record 20 of Set 3 | karratha
# Processing Record 21 of Set 3 | fereydun kenar
# Processing Record 22 of Set 3 | beringovskiy
# Processing Record 23 of Set 3 | lompoc
# Processing Record 24 of Set 3 | komarichi
# Processing Record 25 of Set 3 | shintomi
# Processing Record 26 of Set 3 | urengoy
# Processing Record 27 of Set 3 | hargeysa
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | longyearbyen
# Processing Record 30 of Set 3 | tabou
# Processing Record 31 of Set 3 | zhuhai
# Processing Record 32 of Set 3 | loralai
# Processing Record 33 of Set 3 | sitka
# Processing Record 34 of Set 3 | santa rosa
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | deputatskiy
# Processing Record 37 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 38 of Set 3 | zhigansk
# Processing Record 39 of Set 3 | ambilobe
# Processing Record 40 of Set 3 | anupgarh
# Processing Record 41 of Set 3 | kendari
# Processing Record 42 of Set 3 | esperance
# Processing Record 43 of Set 3 | skagastrond
# City not found. Skipping...
# Processing Record 44 of Set 3 | itoman
# Processing Record 45 of Set 3 | cedral
# Processing Record 46 of Set 3 | kirakira
# Processing Record 47 of Set 3 | faruka
# Processing Record 48 of Set 3 | dovers
# Processing Record 49 of Set 3 | maiduguri
# Processing Record 50 of Set 3 | kamenka
# Processing Record 1 of Set 4 | galiwinku
# City not found. Skipping...
# Processing Record 2 of Set 4 | arandis
# Processing Record 3 of Set 4 | nouadhibou
# Processing Record 4 of Set 4 | nishihara
# Processing Record 5 of Set 4 | luderitz
# Processing Record 6 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 4 | praia da vitoria
# Processing Record 8 of Set 4 | iqaluit
# Processing Record 9 of Set 4 | teguldet
# Processing Record 10 of Set 4 | namibe
# Processing Record 11 of Set 4 | catamarca
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | olafsvik
# Processing Record 14 of Set 4 | port-de-paix
# City not found. Skipping...
# Processing Record 15 of Set 4 | enshi
# Processing Record 16 of Set 4 | ostrovnoy
# Processing Record 17 of Set 4 | stokmarknes
# Processing Record 18 of Set 4 | mayor pablo lagerenza
# Processing Record 19 of Set 4 | victoria
# Processing Record 20 of Set 4 | maputo
# Processing Record 21 of Set 4 | kununurra
# Processing Record 22 of Set 4 | praia
# Processing Record 23 of Set 4 | damietta
# Processing Record 24 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 4 | flin flon
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | henties bay
# Processing Record 28 of Set 4 | tempio pausania
# Processing Record 29 of Set 4 | pevek
# Processing Record 30 of Set 4 | ilhabela
# Processing Record 31 of Set 4 | darapidap
# Processing Record 32 of Set 4 | katsuura
# Processing Record 33 of Set 4 | ketchikan
# Processing Record 34 of Set 4 | vestmannaeyjar
# Processing Record 35 of Set 4 | abha
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | dingle
# Processing Record 39 of Set 4 | jiayuguan
# Processing Record 40 of Set 4 | sorland
# Processing Record 41 of Set 4 | turukhansk
# Processing Record 42 of Set 4 | hanna
# Processing Record 43 of Set 4 | port lincoln
# Processing Record 44 of Set 4 | mildura
# Processing Record 45 of Set 4 | kruisfontein
# Processing Record 46 of Set 4 | aguimes
# Processing Record 47 of Set 4 | mandalgovi
# Processing Record 48 of Set 4 | jacareacanga
# Processing Record 49 of Set 4 | upernavik
# Processing Record 50 of Set 4 | mar del plata
# Processing Record 1 of Set 5 | marshalltown
# Processing Record 2 of Set 5 | ryuo
# Processing Record 3 of Set 5 | lavrentiya
# Processing Record 4 of Set 5 | korla
# Processing Record 5 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | mangan
# Processing Record 9 of Set 5 | hilo
# Processing Record 10 of Set 5 | alice springs
# Processing Record 11 of Set 5 | san cristobal
# Processing Record 12 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 5 | mahon
# Processing Record 14 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 5 | tiarei
# Processing Record 16 of Set 5 | perevoz
# Processing Record 17 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | winnemucca
# Processing Record 19 of Set 5 | bontang
# Processing Record 20 of Set 5 | alyangula
# Processing Record 21 of Set 5 | touros
# Processing Record 22 of Set 5 | nouakchott
# Processing Record 23 of Set 5 | linxia
# Processing Record 24 of Set 5 | tual
# Processing Record 25 of Set 5 | storforshei
# Processing Record 26 of Set 5 | kodinsk
# Processing Record 27 of Set 5 | zenzeli
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | sarahan
# Processing Record 30 of Set 5 | anloga
# Processing Record 31 of Set 5 | liverpool
# Processing Record 32 of Set 5 | bridlington
# Processing Record 33 of Set 5 | krasnyy kut
# Processing Record 34 of Set 5 | sechura
# Processing Record 35 of Set 5 | awjilah
# Processing Record 36 of Set 5 | cabo san lucas
# Processing Record 37 of Set 5 | khatanga
# Processing Record 38 of Set 5 | alta floresta
# Processing Record 39 of Set 5 | auki
# Processing Record 40 of Set 5 | aklavik
# Processing Record 41 of Set 5 | kurilsk
# Processing Record 42 of Set 5 | bac lieu
# Processing Record 43 of Set 5 | kimbe
# Processing Record 44 of Set 5 | port keats
# Processing Record 45 of Set 5 | yerbogachen
# Processing Record 46 of Set 5 | port hardy
# Processing Record 47 of Set 5 | thompson
# Processing Record 48 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 5 | kindu
# Processing Record 50 of Set 5 | dikson
# Processing Record 1 of Set 6 | talara
# Processing Record 2 of Set 6 | larsnes
# Processing Record 3 of Set 6 | walvis bay
# Processing Record 4 of Set 6 | harper
# Processing Record 5 of Set 6 | xalpatlahuac
# Processing Record 6 of Set 6 | faanui
# Processing Record 7 of Set 6 | tiksi
# Processing Record 8 of Set 6 | saskylakh
# Processing Record 9 of Set 6 | ilo
# Processing Record 10 of Set 6 | koubia
# Processing Record 11 of Set 6 | marawi
# Processing Record 12 of Set 6 | bodmin
# Processing Record 13 of Set 6 | semnan
# Processing Record 14 of Set 6 | ust-ilimsk
# Processing Record 15 of Set 6 | tocache
# Processing Record 16 of Set 6 | broken hill
# Processing Record 17 of Set 6 | srednekolymsk
# Processing Record 18 of Set 6 | port hedland
# Processing Record 19 of Set 6 | east london
# Processing Record 20 of Set 6 | bozeman
# Processing Record 21 of Set 6 | acapulco
# Processing Record 22 of Set 6 | basco
# Processing Record 23 of Set 6 | vao
# Processing Record 24 of Set 6 | kuching
# Processing Record 25 of Set 6 | sao filipe
# Processing Record 26 of Set 6 | lapua
# Processing Record 27 of Set 6 | bethel
# Processing Record 28 of Set 6 | haines junction
# Processing Record 29 of Set 6 | narsaq
# Processing Record 30 of Set 6 | pemba
# Processing Record 31 of Set 6 | ola
# Processing Record 32 of Set 6 | arak
# Processing Record 33 of Set 6 | brzi brod
# City not found. Skipping...
# Processing Record 34 of Set 6 | killybegs
# Processing Record 35 of Set 6 | viransehir
# Processing Record 36 of Set 6 | acari
# Processing Record 37 of Set 6 | madang
# Processing Record 38 of Set 6 | bani walid
# Processing Record 39 of Set 6 | lhokseumawe
# Processing Record 40 of Set 6 | hithadhoo
# Processing Record 41 of Set 6 | saint-pierre
# Processing Record 42 of Set 6 | rio gallegos
# Processing Record 43 of Set 6 | sao joao da barra
# Processing Record 44 of Set 6 | dhidhdhoo
# Processing Record 45 of Set 6 | caconda
# Processing Record 46 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 6 | klaksvik
# Processing Record 48 of Set 6 | batagay-alyta
# Processing Record 49 of Set 6 | omboue
# Processing Record 50 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 1 of Set 7 | wahran
# City not found. Skipping...
# Processing Record 2 of Set 7 | cayenne
# Processing Record 3 of Set 7 | humaita
# Processing Record 4 of Set 7 | hofn
# Processing Record 5 of Set 7 | ullapool
# Processing Record 6 of Set 7 | zvishavane
# Processing Record 7 of Set 7 | sarangani
# Processing Record 8 of Set 7 | mae sai
# Processing Record 9 of Set 7 | ustynivka
# Processing Record 10 of Set 7 | gambela
# Processing Record 11 of Set 7 | benjamin constant
# Processing Record 12 of Set 7 | brae
# Processing Record 13 of Set 7 | laguna
# Processing Record 14 of Set 7 | saldanha
# Processing Record 15 of Set 7 | kulhudhuffushi
# Processing Record 16 of Set 7 | esmeraldas
# Processing Record 17 of Set 7 | sarangpur
# Processing Record 18 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 7 | santa maria
# Processing Record 20 of Set 7 | guerrero negro
# Processing Record 21 of Set 7 | te anau
# Processing Record 22 of Set 7 | rawson
# Processing Record 23 of Set 7 | carnarvon
# Processing Record 24 of Set 7 | roald
# Processing Record 25 of Set 7 | ugoofaaru
# Processing Record 26 of Set 7 | richards bay
# Processing Record 27 of Set 7 | isangel
# Processing Record 28 of Set 7 | filingue
# Processing Record 29 of Set 7 | muzquiz
# City not found. Skipping...
# Processing Record 30 of Set 7 | yen bai
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | moron
# Processing Record 33 of Set 7 | mersing
# Processing Record 34 of Set 7 | asau
# Processing Record 35 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 7 | lincoln
# Processing Record 37 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 7 | dekar
# Processing Record 39 of Set 7 | adrar
# Processing Record 40 of Set 7 | prince rupert
# Processing Record 41 of Set 7 | bambous virieux
# Processing Record 42 of Set 7 | vestmanna
# Processing Record 43 of Set 7 | cockburn town
# Processing Record 44 of Set 7 | kloulklubed
# Processing Record 45 of Set 7 | poltavka
# Processing Record 46 of Set 7 | oksfjord
# Processing Record 47 of Set 7 | kushima
# Processing Record 48 of Set 7 | ruatoria
# City not found. Skipping...
# Processing Record 49 of Set 7 | araure
# Processing Record 50 of Set 7 | acajutla
# Processing Record 1 of Set 8 | coquimbo
# Processing Record 2 of Set 8 | waingapu
# Processing Record 3 of Set 8 | manokwari
# Processing Record 4 of Set 8 | thinadhoo
# Processing Record 5 of Set 8 | corrientes
# Processing Record 6 of Set 8 | zhangjiakou
# Processing Record 7 of Set 8 | kavaratti
# Processing Record 8 of Set 8 | rocha
# Processing Record 9 of Set 8 | shorapani
# Processing Record 10 of Set 8 | usinsk
# Processing Record 11 of Set 8 | broome
# Processing Record 12 of Set 8 | dunedin
# Processing Record 13 of Set 8 | borgo san dalmazzo
# Processing Record 14 of Set 8 | ust-kuyga
# Processing Record 15 of Set 8 | diego de almagro
# Processing Record 16 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 8 | zwedru
# Processing Record 19 of Set 8 | zharkent
# Processing Record 20 of Set 8 | le port
# Processing Record 21 of Set 8 | camacupa
# Processing Record 22 of Set 8 | gushikawa
# Processing Record 23 of Set 8 | ardakan
# Processing Record 24 of Set 8 | raipur
# Processing Record 25 of Set 8 | eureka
# Processing Record 26 of Set 8 | mount gambier
# Processing Record 27 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 28 of Set 8 | arinos
# Processing Record 29 of Set 8 | riom
# Processing Record 30 of Set 8 | saint anthony
# Processing Record 31 of Set 8 | fortuna
# Processing Record 32 of Set 8 | tyubuk
# Processing Record 33 of Set 8 | havre-saint-pierre
# Processing Record 34 of Set 8 | manadhoo
# Processing Record 35 of Set 8 | sivas
# Processing Record 36 of Set 8 | lasa
# Processing Record 37 of Set 8 | namatanai
# Processing Record 38 of Set 8 | pisco
# Processing Record 39 of Set 8 | puerto carreno
# Processing Record 40 of Set 8 | whitecourt
# Processing Record 41 of Set 8 | solnechnyy
# Processing Record 42 of Set 8 | dezhou
# Processing Record 43 of Set 8 | tautira
# Processing Record 44 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 8 | apatity
# Processing Record 46 of Set 8 | ridgecrest
# Processing Record 47 of Set 8 | oranjemund
# Processing Record 48 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 49 of Set 8 | magadan
# Processing Record 50 of Set 8 | severobaykalsk
# Processing Record 1 of Set 9 | bougouni
# Processing Record 2 of Set 9 | maua
# Processing Record 3 of Set 9 | bandarbeyla
# Processing Record 4 of Set 9 | ewa beach
# Processing Record 5 of Set 9 | portland
# Processing Record 6 of Set 9 | atasu
# Processing Record 7 of Set 9 | mitu
# Processing Record 8 of Set 9 | hualmay
# Processing Record 9 of Set 9 | ziarat
# Processing Record 10 of Set 9 | maposeni
# Processing Record 11 of Set 9 | bauchi
# Processing Record 12 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 9 | koslan
# Processing Record 14 of Set 9 | bilibino
# Processing Record 15 of Set 9 | yenagoa
# Processing Record 16 of Set 9 | okha
# Processing Record 17 of Set 9 | ouadda
# Processing Record 18 of Set 9 | atikokan
# Processing Record 19 of Set 9 | skjervoy
# Processing Record 20 of Set 9 | clarence town
# Processing Record 21 of Set 9 | tacuarembo
# Processing Record 22 of Set 9 | kargil
# Processing Record 23 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 9 | cabedelo
# Processing Record 25 of Set 9 | merauke
# Processing Record 26 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 9 | labuhan
# Processing Record 28 of Set 9 | raduzhnyy
# Processing Record 29 of Set 9 | skibbereen
# Processing Record 30 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 31 of Set 9 | kontagora
# Processing Record 32 of Set 9 | ojinaga
# Processing Record 33 of Set 9 | shkotovo-22
# City not found. Skipping...
# Processing Record 34 of Set 9 | rio grande
# Processing Record 35 of Set 9 | hai phong
# City not found. Skipping...
# Processing Record 36 of Set 9 | ust-omchug
# Processing Record 37 of Set 9 | kroya
# Processing Record 38 of Set 9 | saint-francois
# Processing Record 39 of Set 9 | takoradi
# Processing Record 40 of Set 9 | lata
# Processing Record 41 of Set 9 | blagoyevo
# Processing Record 42 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 43 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 9 | bagdarin
# Processing Record 45 of Set 9 | neuquen
# Processing Record 46 of Set 9 | metro
# Processing Record 47 of Set 9 | porto novo
# Processing Record 48 of Set 9 | nieuw amsterdam
# Processing Record 49 of Set 9 | anchorage
# Processing Record 50 of Set 9 | taree
# Processing Record 1 of Set 10 | buraydah
# Processing Record 2 of Set 10 | clyde river
# Processing Record 3 of Set 10 | vintar
# Processing Record 4 of Set 10 | dalbandin
# Processing Record 5 of Set 10 | vardo
# Processing Record 6 of Set 10 | chifeng
# Processing Record 7 of Set 10 | isla vista
# Processing Record 8 of Set 10 | manthani
# Processing Record 9 of Set 10 | la ronge
# Processing Record 10 of Set 10 | north bend
# Processing Record 11 of Set 10 | umm kaddadah
# Processing Record 12 of Set 10 | pacific grove
# Processing Record 13 of Set 10 | shenkursk
# Processing Record 14 of Set 10 | yar-sale
# Processing Record 15 of Set 10 | akhtanizovskaya
# Processing Record 16 of Set 10 | sakakah
# Processing Record 17 of Set 10 | ponta do sol
# Processing Record 18 of Set 10 | juruti
# Processing Record 19 of Set 10 | vagur
# Processing Record 20 of Set 10 | kachiry
# Processing Record 21 of Set 10 | poum
# Processing Record 22 of Set 10 | camana
# Processing Record 23 of Set 10 | mpwapwa
# Processing Record 24 of Set 10 | coahuayana
# Processing Record 25 of Set 10 | pergamino
# Processing Record 26 of Set 10 | hutchinson
# Processing Record 27 of Set 10 | katobu
# Processing Record 28 of Set 10 | labrea
# Processing Record 29 of Set 10 | leningradskiy
# Processing Record 30 of Set 10 | kidal
# Processing Record 31 of Set 10 | tashtyp
# Processing Record 32 of Set 10 | ambon
# Processing Record 33 of Set 10 | kitimat
# Processing Record 34 of Set 10 | kerman
# Processing Record 35 of Set 10 | askiz
# Processing Record 36 of Set 10 | upplands-vasby
# City not found. Skipping...
# Processing Record 37 of Set 10 | cordoba
# Processing Record 38 of Set 10 | taksimo
# Processing Record 39 of Set 10 | derzhavinsk
# Processing Record 40 of Set 10 | ayan
# Processing Record 41 of Set 10 | yashkino
# Processing Record 42 of Set 10 | los llanos de aridane
# Processing Record 43 of Set 10 | tuatapere
# Processing Record 44 of Set 10 | kieta
# Processing Record 45 of Set 10 | yuryevets
# Processing Record 46 of Set 10 | hobyo
# Processing Record 47 of Set 10 | baghdogra
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | hamilton
# Processing Record 50 of Set 10 | evanston
# Processing Record 1 of Set 11 | atlantic city
# Processing Record 2 of Set 11 | kerrobert
# Processing Record 3 of Set 11 | mayo
# Processing Record 4 of Set 11 | portage
# Processing Record 5 of Set 11 | barentu
# Processing Record 6 of Set 11 | yeppoon
# Processing Record 7 of Set 11 | huilong
# Processing Record 8 of Set 11 | sept-iles
# Processing Record 9 of Set 11 | mount isa
# Processing Record 10 of Set 11 | kurtamysh
# Processing Record 11 of Set 11 | luena
# Processing Record 12 of Set 11 | hearst
# Processing Record 13 of Set 11 | lufilufi
# Processing Record 14 of Set 11 | tazovskiy
# Processing Record 15 of Set 11 | mandeville
# Processing Record 16 of Set 11 | colorado
# Processing Record 17 of Set 11 | mayumba
# Processing Record 18 of Set 11 | road town
# Processing Record 19 of Set 11 | dombarovskiy
# Processing Record 20 of Set 11 | phek
# Processing Record 21 of Set 11 | qinhuangdao
# Processing Record 22 of Set 11 | vila velha
# Processing Record 23 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 24 of Set 11 | puerto leguizamo
# Processing Record 25 of Set 11 | bathsheba
# Processing Record 26 of Set 11 | oriximina
# Processing Record 27 of Set 11 | council bluffs
# Processing Record 28 of Set 11 | san vicente
# Processing Record 29 of Set 11 | padang
# Processing Record 30 of Set 11 | tinde
# Processing Record 31 of Set 11 | rabak
# Processing Record 32 of Set 11 | pitimbu
# Processing Record 33 of Set 11 | lethem
# Processing Record 34 of Set 11 | the valley
# Processing Record 35 of Set 11 | yanai
# Processing Record 36 of Set 11 | muros
# Processing Record 37 of Set 11 | poya
# Processing Record 38 of Set 11 | northam
# Processing Record 39 of Set 11 | sal rei
# Processing Record 40 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 11 | imbituba
# Processing Record 42 of Set 11 | roma
# Processing Record 43 of Set 11 | iskateley
# Processing Record 44 of Set 11 | juneau
# Processing Record 45 of Set 11 | krasnyy luch
# Processing Record 46 of Set 11 | villa carlos paz
# Processing Record 47 of Set 11 | paragominas
# Processing Record 48 of Set 11 | karlstad
# Processing Record 49 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 11 | sorkjosen
# Processing Record 1 of Set 12 | at-bashi
# Processing Record 2 of Set 12 | half moon bay
# Processing Record 3 of Set 12 | zhezkazgan
# Processing Record 4 of Set 12 | moose factory
# Processing Record 5 of Set 12 | ukiah
# Processing Record 6 of Set 12 | giyani
# Processing Record 7 of Set 12 | san joaquin
# Processing Record 8 of Set 12 | tharad
# Processing Record 9 of Set 12 | cururupu
# Processing Record 10 of Set 12 | veracruz
# Processing Record 11 of Set 12 | avera
# Processing Record 12 of Set 12 | tilichiki
# Processing Record 13 of Set 12 | lazaro cardenas
# Processing Record 14 of Set 12 | ofunato
# Processing Record 15 of Set 12 | college
# Processing Record 16 of Set 12 | springdale
# Processing Record 17 of Set 12 | bairiki
# Processing Record 18 of Set 12 | markova
# Processing Record 19 of Set 12 | teknaf
# Processing Record 20 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 21 of Set 12 | jabiru
# City not found. Skipping...
# Processing Record 22 of Set 12 | atambua
# Processing Record 23 of Set 12 | siniscola
# Processing Record 24 of Set 12 | ngunguru
# Processing Record 25 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 12 | xingcheng
# Processing Record 27 of Set 12 | preobrazheniye
# Processing Record 28 of Set 12 | prince george
# Processing Record 29 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 30 of Set 12 | udayagiri
# Processing Record 31 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 12 | havoysund
# Processing Record 33 of Set 12 | hwange
# Processing Record 34 of Set 12 | nome
# Processing Record 35 of Set 12 | busayra
# Processing Record 36 of Set 12 | shelburne
# Processing Record 37 of Set 12 | novopokrovka
# Processing Record 38 of Set 12 | tahe
# Processing Record 39 of Set 12 | margate
# Processing Record 40 of Set 12 | lulea
# Processing Record 41 of Set 12 | zheleznodorozhnyy
# Processing Record 42 of Set 12 | santa cruz de tenerife
# Processing Record 43 of Set 12 | bom jesus
# Processing Record 44 of Set 12 | genhe
# Processing Record 45 of Set 12 | clinton
# Processing Record 46 of Set 12 | mitsamiouli
# Processing Record 47 of Set 12 | murom
# Processing Record 48 of Set 12 | xaltianguis
# Processing Record 49 of Set 12 | tornio
# Processing Record 50 of Set 12 | karasburg
# Processing Record 1 of Set 13 | lorengau
# Processing Record 2 of Set 13 | hibbing
# Processing Record 3 of Set 13 | artyom
# Processing Record 4 of Set 13 | swan river
# Processing Record 5 of Set 13 | charlestown
# Processing Record 6 of Set 13 | campos do jordao
# Processing Record 7 of Set 13 | luwingu
# Processing Record 8 of Set 13 | tombouctou
# Processing Record 9 of Set 13 | santa isabel do rio negro
# Processing Record 10 of Set 13 | belyy yar
# Processing Record 11 of Set 13 | los andes
# Processing Record 12 of Set 13 | samarai
# Processing Record 13 of Set 13 | xam nua
# Processing Record 14 of Set 13 | maragheh
# Processing Record 15 of Set 13 | monrovia
# Processing Record 16 of Set 13 | mogadishu
# Processing Record 17 of Set 13 | san martin
# Processing Record 18 of Set 13 | santa comba
# Processing Record 19 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 20 of Set 13 | la rioja
# Processing Record 21 of Set 13 | quatre cocos
# Processing Record 22 of Set 13 | uige
# Processing Record 23 of Set 13 | sobolevo
# Processing Record 24 of Set 13 | whitehorse
# Processing Record 25 of Set 13 | kushalgarh
# Processing Record 26 of Set 13 | santa marta
# Processing Record 27 of Set 13 | suhaia
# Processing Record 28 of Set 13 | port moresby
# Processing Record 29 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 13 | sao fidelis
# Processing Record 31 of Set 13 | zatyshshya
# Processing Record 32 of Set 13 | maryanovka
# City not found. Skipping...
# Processing Record 33 of Set 13 | sebnitz
# Processing Record 34 of Set 13 | ulaangom
# Processing Record 35 of Set 13 | vicuna
# Processing Record 36 of Set 13 | fairbanks
# Processing Record 37 of Set 13 | high level
# Processing Record 38 of Set 13 | nizhnyaya tavda
# Processing Record 39 of Set 13 | karamea
# City not found. Skipping...
# Processing Record 40 of Set 13 | prachuap khiri khan
# Processing Record 41 of Set 13 | shimoda
# Processing Record 42 of Set 13 | beboto
# Processing Record 43 of Set 13 | pangoa
# Processing Record 44 of Set 13 | verkhnevilyuysk
# Processing Record 45 of Set 13 | phangnga
# Processing Record 46 of Set 13 | zihuatanejo
# Processing Record 47 of Set 13 | copiapo
# Processing Record 48 of Set 13 | champasak
# Processing Record 49 of Set 13 | bokoro
# Processing Record 50 of Set 13 | najran
# Processing Record 1 of Set 14 | moundou
# Processing Record 2 of Set 14 | batavia
# Processing Record 3 of Set 14 | pangai
# Processing Record 4 of Set 14 | kichera
# Processing Record 5 of Set 14 | gallup
# Processing Record 6 of Set 14 | tuysarkan
# City not found. Skipping...
# Processing Record 7 of Set 14 | linxi
# Processing Record 8 of Set 14 | charagua
# Processing Record 9 of Set 14 | codrington
# Processing Record 10 of Set 14 | plymouth
# Processing Record 11 of Set 14 | victoria point
# Processing Record 12 of Set 14 | esso
# Processing Record 13 of Set 14 | kristianstad
# Processing Record 14 of Set 14 | komsomolskiy
# Processing Record 15 of Set 14 | topolobampo
# Processing Record 16 of Set 14 | paucartambo
# City not found. Skipping...
# Processing Record 17 of Set 14 | tanjung morawa
# City not found. Skipping...
# Processing Record 18 of Set 14 | plettenberg bay
# Processing Record 19 of Set 14 | kasongo-lunda
# Processing Record 20 of Set 14 | ahipara
# Processing Record 21 of Set 14 | ranong
# Processing Record 22 of Set 14 | sainte-maxime
# Processing Record 23 of Set 14 | mahibadhoo
# Processing Record 24 of Set 14 | nguruka
# Processing Record 25 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 26 of Set 14 | simao
# Processing Record 27 of Set 14 | santiago del estero
# Processing Record 28 of Set 14 | arlit
# Processing Record 29 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 14 | necochea
# Processing Record 31 of Set 14 | mocajuba
# Processing Record 32 of Set 14 | tiznit
# Processing Record 33 of Set 14 | mareeba
# Processing Record 34 of Set 14 | arman
# Processing Record 35 of Set 14 | porterville
# Processing Record 36 of Set 14 | galveston
# Processing Record 37 of Set 14 | biograd na moru
# Processing Record 38 of Set 14 | aykhal
# Processing Record 39 of Set 14 | taoudenni
# Processing Record 40 of Set 14 | ulladulla
# Processing Record 41 of Set 14 | gravelbourg
# Processing Record 42 of Set 14 | hambantota
# Processing Record 43 of Set 14 | astoria
# Processing Record 44 of Set 14 | bonthe
# Processing Record 45 of Set 14 | dibulla
# Processing Record 46 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 14 | port blair
# Processing Record 48 of Set 14 | kerouane
# Processing Record 49 of Set 14 | nguru
# Processing Record 50 of Set 14 | labuan
# Processing Record 1 of Set 15 | ailigandi
# Processing Record 2 of Set 15 | takayama
# Processing Record 3 of Set 15 | lakhtar
# Processing Record 4 of Set 15 | novikovo
# Processing Record 5 of Set 15 | hohhot
# Processing Record 6 of Set 15 | qena
# Processing Record 7 of Set 15 | bronnoysund
# Processing Record 8 of Set 15 | bruiu
# Processing Record 9 of Set 15 | qaqortoq
# Processing Record 10 of Set 15 | freetown
# Processing Record 11 of Set 15 | chaah
# Processing Record 12 of Set 15 | berehove
# Processing Record 13 of Set 15 | camacha
# Processing Record 14 of Set 15 | doha
# Processing Record 15 of Set 15 | cap-aux-meules
# Processing Record 16 of Set 15 | kapoeta
# Processing Record 17 of Set 15 | antalaha
# Processing Record 18 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 15 | gao
# Processing Record 21 of Set 15 | vung tau
# Processing Record 22 of Set 15 | quelimane
# Processing Record 23 of Set 15 | shubarkuduk
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Zeya      RU  53.7500  127.2667     28.71        74          52
# 1         Ossora      RU  59.2353  163.0719     15.17        88          19
# 2  Bystryy Istok      RU  52.3710   84.3873     61.27        30         100
# 3      Nchelenge      ZM  -9.3451   28.7340     77.20        73          18
# 4          Aswan      EG  24.0934   32.9070    108.70         6         100
# 5           Hami      CN  42.8000   93.4500     61.32        13           0
# 6          Kapaa      US  22.0752 -159.3190     70.12        97          17
# 7         Shingu      JP  33.7333  135.9833     58.33        89          83
# 8     Butaritari      KI   3.0707  172.7902     81.37        75          25
# 9        Ballina      AU -28.8667  153.5667     65.01        93          75
#
#    Wind Speed Current Description
# 0        1.52       broken clouds
# 1        7.43          few clouds
# 2        4.81     overcast clouds
# 3        4.16          light rain
# 4        8.05     overcast clouds
# 5        5.12           clear sky
# 6       12.33       moderate rain
# 7        7.56       broken clouds
# 8       12.19    scattered clouds
# 9        6.91       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
